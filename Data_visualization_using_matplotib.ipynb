# %%
import matplotlib.pyplot as plt

# %%
x=[2,4,6,8,10]
y=[1,2,3,4,5]

# %%
#x lable
plt.xlabel("sales")
#y lable
plt.ylabel("profit")
plt.title("sales vs profit")

#plot values
plt.plot(x,y)

# %%
y
# Out:
# [1, 2, 3, 4, 5]

# %%
#x lable
plt.xlabel("sales")
#y lable
plt.ylabel("profit")
plt.title("sales vs profit")

#plot values
plt.plot(x,y,linestyle='dotted')

# %%
#x lable
plt.xlabel("sales")
#y lable
plt.ylabel("profit")
plt.title("sales vs profit")

#plot values
plt.plot(x,y,color='b',marker='+',ms=25)

# %%
#x lable
plt.xlabel("sales")
#y lable
plt.ylabel("profit")
plt.title("sales vs profit")

#plot values)
plt.plot(x,y,color='r',linestyle='dotted')

# %%
#x lable
plt.xlabel("sales")
#y lable
plt.ylabel("profit")
plt.title("sales vs profit")

#plot values
plt.bar(x,y)
# Out:
# <BarContainer object of 5 artists>

# %%
#x lable
plt.xlabel("sales")
#y lable
plt.ylabel("profit")
plt.title("sales vs profit")

#plot values
plt.scatter(x,y,marker='+')

# %%
#x lable
plt.xlabel("sales")
#y lable
plt.ylabel("profit")
plt.title("sales vs profit")

#plot values

plt.bar(y,x)
plt.scatter(x,y,marker='+')

# %%
#subplot
import numpy as np
a=np.array([44,55,66,77,88,99])
b=np.array([41,52,63,74,85,96])
c=np.array([14,15,16,17,18,19])
d=np.array([4,50,8,70,88,90])

plt.plot(a,d)
#plot1
plt.subplot(2,2,1)
plt.plot(a,d)

#plot2
plt.subplot(2,2,2)
plt.plot(c,d)

# %%
plt.plot(a,d)
#plot1
plt.subplot(2,2,4)
plt.plot(a,d)

#plot2
plt.subplot(2,2,1)
plt.plot(c,d)

# %%
plt.plot(a,d)
#plot1
plt.subplot(2,2,3)
plt.plot(a,d)

#plot2
plt.subplot(2,2,4)
plt.plot(c,d)

# %%
#plot1
plt.subplot(2,2,4)
plt.plot(a,d)

#plot2
plt.subplot(2,2,3)
plt.plot(c,d)

#plot3
plt.subplot(2,2,2)
plt.plot(b,d)

#plot4
plt.subplot(2,2,1)
plt.plot(a,d)

# %%
#plot1
plt.subplot(3,2,3)
plt.plot(a,d)

#plot2
plt.subplot(3,2,2)
plt.plot(c,d)

#plot3
plt.subplot(3,2,5)
plt.plot(b,d)

# %%
#plot1
plt.subplot(2,2,1)
plt.plot(a,c)

#plot2
plt.subplot(2,2,4)
plt.plot(c,d)

#plot3
plt.subplot(2,2,3)
plt.plot(b,d)

#plot4
plt.subplot(2,2,2)
plt.plot(a,d)

# %%
#Histogram
data1=np.random.normal(150,10,250)

# %%
len(data1)
# Out:
# 250

# %%
plt.hist(data1,bins=20)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data=np.array([44,55,66,77,88,99,55])
plt.hist(data)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#create numpy array for 18 student containg marks of and create histogram with bin size 10
data2=np.array([80,76,67,54,77,89,86,57,69,70])
plt.hist(data2)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#pie chart

#create dataset
cars=['audi','BMW','tata','Honda']
sale=[88,100,89,610]
#create pie chart
plt.pie(sale,labels=cars)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Out:
# list
